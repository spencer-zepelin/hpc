# %%
# todo: fix color scale across plotsclear

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
f = open('f0.txt', 'r')
x = np.loadtxt(f)
ax = sns.heatmap(x, xticklabels=50, yticklabels=50)

sns.plt.show()

# %%
sns.plt.clf()
f.close()
f = open('f1.txt', 'r')
x = np.loadtxt(f)
ax1 = sns.heatmap(x, xticklabels=50, yticklabels=50)
sns.plt.show()

# %%
sns.plt.clf()
f.close()
f = open('f2.txt', 'r')
x = np.loadtxt(f)
ax1 = sns.heatmap(x, xticklabels=50, yticklabels=50)
sns.plt.show()

# %%
sns.plt.clf()
f.close()
f = open('fp0.txt', 'r')
x = np.loadtxt(f)
ax = sns.heatmap(x, xticklabels=50, yticklabels=50)
sns.plt.show()

# %%
sns.plt.clf()
f.close()
f = open('fp1.txt', 'r')
x = np.loadtxt(f)
ax1 = sns.heatmap(x, xticklabels=50, yticklabels=50)
sns.plt.show()

# %%
sns.plt.clf()
f.close()
f = open('fp2.txt', 'r')
x = np.loadtxt(f)
ax1 = sns.heatmap(x, xticklabels=50, yticklabels=50)
sns.plt.show()

# %%
f.close()
